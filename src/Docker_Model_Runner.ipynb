# %%
from langchain_openai import ChatOpenAI

# %%
llm_local = ChatOpenAI(
    base_url= "http://localhost:12434/engines/llama.cpp/v1",
    model="ai/qwen3:0.6B-Q4_0", temperature=0)

### NEED TO DOUNLOAD THE MODEL FROM DOOCKER HUB AND SETUP BASEURL PROPERLY ###

# %%
llm_local.invoke("What is AI?")
# Out:
# AIMessage(content='Artificial Intelligence (AI) refers to the field of study that involves creating machines and systems that can perform tasks that typically require human intelligence, such as learning, reasoning, problem-solving, and decision-making. AI is a broad concept that can be broken down into several key areas:\n\n1. **Machine Learning**: A subset of AI that enables machines to improve their performance over time as they learn from data. This is a core component of AI.\n\n2. **Natural Language Processing (NLP)**: AI that enables machines to understand and generate human language, such as in chatbots or voice assistants.\n\n3. **Computer Vision**: AI that enables machines to interpret and understand images, like in facial recognition or object detection.\n\n4. **Speech Recognition**: AI that allows machines to understand and generate speech, such as in voice assistants or voice recognition systems.\n\n5. **Expert Systems**: AI that simulate human decision-making in specific
# ...

# %% [markdown]
# # To create embeddings and build your vetor db --> search for relevance embedding model, textsplitter and do the REST
